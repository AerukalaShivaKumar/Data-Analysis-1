# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\Sgoud\Clean_dataframe.csv",index_col=0)
df
# Out:
#                 dateCrawled  \
# 0       2016-03-24 10:58:45
# 1       2016-03-14 12:52:21
# 2       2016-03-17 16:54:04
# 3       2016-03-31 17:25:20
# 4       2016-04-04 17:36:23
# ...                     ...
# 333848  2016-03-14 17:48:27
# 333849  2016-03-05 19:56:21
# 333850  2016-03-19 18:57:12
# 333851  2016-03-20 19:41:08
# 333852  2016-03-07 19:39:19
#
#                                                      name  seller offerType  \
# 0                                    A5_Sportback_2.7_Tdi  privat   Angebot
# 1                          Jeep_Grand_Cherokee_"Overland"  privat   Angebot
# 2                                      GOLF_4_1_4__3T�RER  privat   Angebot
# 3                          Skoda_Fabia_1.4_TDI_PD_Classic  privat   Angebot
# 4       BMW_316i___e36_Limousine___Bastlerfahrzeug__Ex...  privat   Angebot
# ...                                                   ...     ...       ...
# 333848                         Suche_t4___vito_ab_6_sitze  privat   Angebot
# 333849              Smart_smart_leistungssteigerung_100ps  privat   Angebot
# 333850                 Volkswagen_Multivan_T4_TDI_7DC_UY2  privat   Angebot
# 333851                             VW_Golf_Kombi_1_9l_TDI  privat   Angebot
# 333852       BMW_M135i_vollausgestattet_NP_52.720____Euro  privat   Angebot
#
#         price   abtest    vehicleType  yearOfRegistration        gearbox  \
# 0       18300     test          coupe                2011        manuell
# 1        9800     test            suv                2004      automatik
# 2        1500     test     kleinwagen                2001        manuell
# 3        3600     test     kleinwagen                2008        manuell
# 4         650     test      limousine                1995        manuell
# ...       ...      ...            ...                 ...            ...
# 333848   2200     test  Not Mentioned                2005  Not Mentioned
# 333849   1199     test         cabrio                2000      automatik
# 333850   9200     test            bus                1996        manuell
# 333851   3400     test          kombi                2002        manuell
# 333852  28990  control      limousine                2013        manuell
#
#         powerPS          model  kilometer  monthOfRegistration       fuelType  \
# 0           190  Not Mentioned     125000                    5         diesel
# 1           163          grand     125000                    8         diesel
# 2            75           golf     150000                    6         benzin
# 3            69          fabia      90000                    7         diesel
# 4           102            3er     150000                   10         benzin
# ...         ...            ...        ...                  ...            ...
# 333848        0  Not Mentioned      20000                    1  Not Mentioned
# 333849      101         fortwo     125000                    3         benzin
# 333850      102    transporter     150000                    3         diesel
# 333851      100           golf     150000                    6         diesel
# 333852      320        m_reihe      50000                    8         benzin
#
#                  brand notRepairedDamage          dateCreated  nrOfPictures  \
# 0                 audi                ja  2016-03-24 00:00:00             0
# 1                 jeep     Not Mentioned  2016-03-14 00:00:00             0
# 2           volkswagen              nein  2016-03-17 00:00:00             0
# 3                skoda              nein  2016-03-31 00:00:00             0
# 4                  bmw                ja  2016-04-04 00:00:00             0
# ...                ...               ...                  ...           ...
# 333848  sonstige_autos     Not Mentioned  2016-03-14 00:00:00             0
# 333849           smart              nein  2016-03-05 00:00:00             0
# 333850      volkswagen              nein  2016-03-19 00:00:00             0
# 333851      volkswagen     Not Mentioned  2016-03-20 00:00:00             0
# 333852             bmw              nein  2016-03-07 00:00:00             0
#
#         postalCode             lastSeen
# 0            66954  2016-04-07 01:46:50
# 1            90480  2016-04-05 12:47:46
# 2            91074  2016-03-17 17:40:17
# 3            60437  2016-04-06 10:17:21
# 4            33775  2016-04-06 19:17:07
# ...            ...                  ...
# 333848       39576  2016-04-06 00:46:52
# 333849       26135  2016-03-11 18:17:12
# 333850       87439  2016-04-07 07:15:26
# 333851       40764  2016-03-24 12:45:21
# 333852       73326  2016-03-22 03:17:10
#
# [333853 rows x 20 columns]

# %% [markdown]
# # 1.The memory usage of the data is around 6.1 mb.How can we
# ## reduce the memory usage of the data set?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 333853 entries, 0 to 333852
# Data columns (total 20 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   dateCrawled          333853 non-null  object
#  1   name                 333853 non-null  object
#  2   seller               333853 non-null  object
#  3   offerType            333853 non-null  object
#  4   price                333853 non-null  int64
#  5   abtest               333853 non-null  object
#  6   vehicleType          333853 non-null  object
#  7   yearOfRegistration   333853 non-null  int64
#  8   gearbox              333853 non-null  object
#  9   powerPS              333853 non-null  int64
#  10  model                333853 non-null  object
#  11  kilometer            333853 non-null  int64
#  12  monthOfRegistration  333853 non-null  int64
#  13  fuelType             333853 non-null  object
#  14  brand                333853 non-null  object
#  15  notRepairedDamage    333853 non-null  object
#  16  dateCreated          333853 non-null  object
#  17  nrOfPictures         333853 non-null  int64
#  18  postalCode           333853 non-null  int64
#  19  lastSeen             333853 non-null  object
# dtypes: int64(7), object(13)
# memory usage: 53.5+ MB

# %%
df["price"]
# Out:
# 0         18300
# 1          9800
# 2          1500
# 3          3600
# 4           650
#           ...
# 333848     2200
# 333849     1199
# 333850     9200
# 333851     3400
# 333852    28990
# Name: price, Length: 333853, dtype: int64

# %%
df['price'].memory_usage()
# Out:
# 5341648

# %%
df["price"].max()
# Out:
# 2147483647

# %%
df['price'] = df['price'].astype('int32')

# %%
df["price"].max()
# Out:
# 2147483647

# %%
df['powerPS'] = df['powerPS'].astype('int16')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 333853 entries, 0 to 333852
# Data columns (total 20 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   dateCrawled          333853 non-null  object
#  1   name                 333853 non-null  object
#  2   seller               333853 non-null  object
#  3   offerType            333853 non-null  object
#  4   price                333853 non-null  int64
#  5   abtest               333853 non-null  object
#  6   vehicleType          333853 non-null  object
#  7   yearOfRegistration   333853 non-null  int64
#  8   gearbox              333853 non-null  object
#  9   powerPS              333853 non-null  int16
#  10  model                333853 non-null  object
#  11  kilometer            333853 non-null  int64
#  12  monthOfRegistration  333853 non-null  int64
#  13  fuelType             333853 non-null  object
#  14  brand                333853 non-null  object
#  15  notRepairedDamage    333853 non-null  object
#  16  dateCreated          333853 non-null  object
#  17  nrOfPictures         333853 non-null  int64
#  18  postalCode           333853 non-null  int64
#  19  lastSeen             333853 non-null  object
# dtypes: int16(1), int64(6), object(13)
# memory usage: 51.6+ MB

# %%
df['yearOfRegistration'] = df['yearOfRegistration'].astype('int32')
df['kilometer'] = df['kilometer'].astype('int32')
df['monthOfRegistration'] = df['monthOfRegistration'].astype('int32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 333853 entries, 0 to 333852
# Data columns (total 20 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   dateCrawled          333853 non-null  object
#  1   name                 333853 non-null  object
#  2   seller               333853 non-null  object
#  3   offerType            333853 non-null  object
#  4   price                333853 non-null  int64
#  5   abtest               333853 non-null  object
#  6   vehicleType          333853 non-null  object
#  7   yearOfRegistration   333853 non-null  int32
#  8   gearbox              333853 non-null  object
#  9   powerPS              333853 non-null  int16
#  10  model                333853 non-null  object
#  11  kilometer            333853 non-null  int32
#  12  monthOfRegistration  333853 non-null  int32
#  13  fuelType             333853 non-null  object
#  14  brand                333853 non-null  object
#  15  notRepairedDamage    333853 non-null  object
#  16  dateCreated          333853 non-null  object
#  17  nrOfPictures         333853 non-null  int64
#  18  postalCode           333853 non-null  int64
#  19  lastSeen             333853 non-null  object
# dtypes: int16(1), int32(3), int64(3), object(13)
# memory usage: 47.8+ MB

# %%
df['nrOfPictures'] = df['nrOfPictures'].astype('int8')
df['postalCode'] = df['postalCode'].astype('int8')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 333853 entries, 0 to 333852
# Data columns (total 20 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   dateCrawled          333853 non-null  object
#  1   name                 333853 non-null  object
#  2   seller               333853 non-null  object
#  3   offerType            333853 non-null  object
#  4   price                333853 non-null  int64
#  5   abtest               333853 non-null  object
#  6   vehicleType          333853 non-null  object
#  7   yearOfRegistration   333853 non-null  int32
#  8   gearbox              333853 non-null  object
#  9   powerPS              333853 non-null  int16
#  10  model                333853 non-null  object
#  11  kilometer            333853 non-null  int32
#  12  monthOfRegistration  333853 non-null  int32
#  13  fuelType             333853 non-null  object
#  14  brand                333853 non-null  object
#  15  notRepairedDamage    333853 non-null  object
#  16  dateCreated          333853 non-null  object
#  17  nrOfPictures         333853 non-null  int8
#  18  postalCode           333853 non-null  int8
#  19  lastSeen             333853 non-null  object
# dtypes: int16(1), int32(3), int64(1), int8(2), object(13)
# memory usage: 43.3+ MB

# %% [markdown]
# # 2.What is the Average price of vehicle by fuel type and gearbox
# ## type.Give a plot

# %%
plot = df[['fuelType','gearbox',"price"]]

# %%
plot
# Out:
#              fuelType        gearbox  price
# 0              diesel        manuell  18300
# 1              diesel      automatik   9800
# 2              benzin        manuell   1500
# 3              diesel        manuell   3600
# 4              benzin        manuell    650
# ...               ...            ...    ...
# 333848  Not Mentioned  Not Mentioned   2200
# 333849         benzin      automatik   1199
# 333850         diesel        manuell   9200
# 333851         diesel        manuell   3400
# 333852         benzin        manuell  28990
#
# [333853 rows x 3 columns]

# %%
average_prices = df.groupby(['fuelType','gearbox'])['price'].mean().reset_index()
average_price =average_prices[average_prices['fuelType']!="andere"]
average_price
# Out:
#          fuelType        gearbox         price
# 0   Not Mentioned  Not Mentioned  51289.820840
# 1   Not Mentioned      automatik   6354.584380
# 2   Not Mentioned        manuell  18589.351103
# 6          benzin  Not Mentioned   7641.271655
# 7          benzin      automatik  12756.009229
# 8          benzin        manuell   6716.761043
# 9             cng  Not Mentioned   4328.285714
# 10            cng      automatik   6737.717949
# 11            cng        manuell   4672.871951
# 12         diesel  Not Mentioned   4717.075945
# 13         diesel      automatik  19181.187384
# 14         diesel        manuell   7507.033376
# 15        elektro  Not Mentioned   4637.090909
# 16        elektro      automatik  24028.959459
# 17        elektro        manuell   3977.181818
# 18         hybrid  Not Mentioned  14540.000000
# 19         hybrid      automatik  15346.877828
# 20         hybrid        manuell  12539.340909
# 21            lpg  Not Mentioned   3108.607143
# 22            lpg      automatik  23417.286920
# 23            lpg        manuell   3359.265594

# %%
average_price
# Out:
#          fuelType        gearbox         price
# 0   Not Mentioned  Not Mentioned  51289.820840
# 1   Not Mentioned      automatik   6354.584380
# 2   Not Mentioned        manuell  18589.351103
# 6          benzin  Not Mentioned   7641.271655
# 7          benzin      automatik  12756.009229
# 8          benzin        manuell   6716.761043
# 9             cng  Not Mentioned   4328.285714
# 10            cng      automatik   6737.717949
# 11            cng        manuell   4672.871951
# 12         diesel  Not Mentioned   4717.075945
# 13         diesel      automatik  19181.187384
# 14         diesel        manuell   7507.033376
# 15        elektro  Not Mentioned   4637.090909
# 16        elektro      automatik  24028.959459
# 17        elektro        manuell   3977.181818
# 18         hybrid  Not Mentioned  14540.000000
# 19         hybrid      automatik  15346.877828
# 20         hybrid        manuell  12539.340909
# 21            lpg  Not Mentioned   3108.607143
# 22            lpg      automatik  23417.286920
# 23            lpg        manuell   3359.265594

# %%
sns.barplot(x=average_price['fuelType'],y=average_price['price'],hue=average_price['gearbox'])
plt.xticks(rotation=45)
plt.show()

# %%
average_price_1=average_prices[average_prices['fuelType']=="andere"]
average_price_1
# Out:
#   fuelType        gearbox         price
# 3   andere  Not Mentioned  2.549821e+03
# 4   andere      automatik  8.701464e+03
# 5   andere        manuell  2.147752e+07

# %%
sns.barplot(x=average_price_1['fuelType'],y=average_price_1['price'],hue=average_price_1['gearbox'])
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # 3.What is the Average power of a vehicle by vehicle type and
# ## gearbox type.Give a plot

# %%
df
# Out:
#                 dateCrawled  \
# 0       2016-03-24 10:58:45
# 1       2016-03-14 12:52:21
# 2       2016-03-17 16:54:04
# 3       2016-03-31 17:25:20
# 4       2016-04-04 17:36:23
# ...                     ...
# 333848  2016-03-14 17:48:27
# 333849  2016-03-05 19:56:21
# 333850  2016-03-19 18:57:12
# 333851  2016-03-20 19:41:08
# 333852  2016-03-07 19:39:19
#
#                                                      name  seller offerType  \
# 0                                    A5_Sportback_2.7_Tdi  privat   Angebot
# 1                          Jeep_Grand_Cherokee_"Overland"  privat   Angebot
# 2                                      GOLF_4_1_4__3T�RER  privat   Angebot
# 3                          Skoda_Fabia_1.4_TDI_PD_Classic  privat   Angebot
# 4       BMW_316i___e36_Limousine___Bastlerfahrzeug__Ex...  privat   Angebot
# ...                                                   ...     ...       ...
# 333848                         Suche_t4___vito_ab_6_sitze  privat   Angebot
# 333849              Smart_smart_leistungssteigerung_100ps  privat   Angebot
# 333850                 Volkswagen_Multivan_T4_TDI_7DC_UY2  privat   Angebot
# 333851                             VW_Golf_Kombi_1_9l_TDI  privat   Angebot
# 333852       BMW_M135i_vollausgestattet_NP_52.720____Euro  privat   Angebot
#
#         price   abtest    vehicleType  yearOfRegistration        gearbox  \
# 0       18300     test          coupe                2011        manuell
# 1        9800     test            suv                2004      automatik
# 2        1500     test     kleinwagen                2001        manuell
# 3        3600     test     kleinwagen                2008        manuell
# 4         650     test      limousine                1995        manuell
# ...       ...      ...            ...                 ...            ...
# 333848   2200     test  Not Mentioned                2005  Not Mentioned
# 333849   1199     test         cabrio                2000      automatik
# 333850   9200     test            bus                1996        manuell
# 333851   3400     test          kombi                2002        manuell
# 333852  28990  control      limousine                2013        manuell
#
#         powerPS          model  kilometer  monthOfRegistration       fuelType  \
# 0           190  Not Mentioned     125000                    5         diesel
# 1           163          grand     125000                    8         diesel
# 2            75           golf     150000                    6         benzin
# 3            69          fabia      90000                    7         diesel
# 4           102            3er     150000                   10         benzin
# ...         ...            ...        ...                  ...            ...
# 333848        0  Not Mentioned      20000                    1  Not Mentioned
# 333849      101         fortwo     125000                    3         benzin
# 333850      102    transporter     150000                    3         diesel
# 333851      100           golf     150000                    6         diesel
# 333852      320        m_reihe      50000                    8         benzin
#
#                  brand notRepairedDamage          dateCreated  nrOfPictures  \
# 0                 audi                ja  2016-03-24 00:00:00             0
# 1                 jeep     Not Mentioned  2016-03-14 00:00:00             0
# 2           volkswagen              nein  2016-03-17 00:00:00             0
# 3                skoda              nein  2016-03-31 00:00:00             0
# 4                  bmw                ja  2016-04-04 00:00:00             0
# ...                ...               ...                  ...           ...
# 333848  sonstige_autos     Not Mentioned  2016-03-14 00:00:00             0
# 333849           smart              nein  2016-03-05 00:00:00             0
# 333850      volkswagen              nein  2016-03-19 00:00:00             0
# 333851      volkswagen     Not Mentioned  2016-03-20 00:00:00             0
# 333852             bmw              nein  2016-03-07 00:00:00             0
#
#         postalCode             lastSeen
# 0             -118  2016-04-07 01:46:50
# 1              112  2016-04-05 12:47:46
# 2              -62  2016-03-17 17:40:17
# 3               21  2016-04-06 10:17:21
# 4              -17  2016-04-06 19:17:07
# ...            ...                  ...
# 333848        -104  2016-04-06 00:46:52
# 333849          23  2016-03-11 18:17:12
# 333850        -113  2016-04-07 07:15:26
# 333851          60  2016-03-24 12:45:21
# 333852         110  2016-03-22 03:17:10
#
# [333853 rows x 20 columns]

# %%
sns.barplot(x=df['vehicleType'],y=df['powerPS'],hue=df['gearbox'])
plt.xticks(rotation=45)
plt.title("Average power of a vechile type and gearbox type")
plt.show()

# %% [markdown]
# # 4.What is the Average price of a vehicle by brand as well as
# ## vehicle type.Use heatmap to explain this

# %%
df1 = df[['brand','vehicleType','price']]

# %%
sns.set_theme(palette='pastel')
plt.figure(figsize=(30,20))
heat_table = df1.pivot_table(values='price',index='brand',columns='vehicleType',aggfunc=np.median)
sns.heatmap(heat_table,cmap='Greens',annot=True)
plt.show()

# %%
heat_table
# Out:
# vehicleType     Not Mentioned   andere      bus   cabrio    coupe  kleinwagen  \
# brand
# alfa_romeo             1050.0   1300.0      NaN   6000.0   4250.0      4550.0
# audi                   2780.0   3725.0   3650.0  10900.0  15000.0      4990.0
# bmw                    2500.0   1600.0  28749.5   8990.0   4499.0      2200.0
# chevrolet              2670.0   9999.0   4250.0  26250.0  14500.0      2650.0
# chrysler               1600.0   3419.0   1700.0   3500.0   8500.0      2225.0
# citroen                1500.0   2000.0   3150.0   3316.5   2525.0      2600.0
# dacia                  3200.0   4300.0   8775.0      NaN      NaN      4200.0
# daewoo                  700.0    999.0   1224.5    900.0    299.0      1150.0
# daihatsu                650.0    450.0    999.5   7999.0      NaN      1000.0
# fiat                   1150.0   2790.0   2750.0   7649.5   2222.0      1500.0
# ford                   1150.0   2600.0   4250.0   2894.5   2599.0      1290.0
# honda                  1400.0   1990.0   4250.0   2895.0   1990.0      2100.0
# hyundai                2250.0   2650.0   2500.0    950.0   2900.0      2800.0
# jaguar                 3200.0      NaN      NaN  33440.0  22325.0     18500.0
# jeep                   3925.0  15300.0   7000.0   1350.0      NaN         NaN
# kia                    2200.0   2099.5   2490.0  10000.0   5700.0      3294.5
# lada                   2500.0   3925.0   3500.0      0.0      NaN       850.0
# lancia                  995.0      NaN   2925.0  17900.0   5445.0       999.0
# land_rover             3325.0   7000.0      NaN   3550.0      NaN         NaN
# mazda                  1190.0   1125.0   2690.0   4444.0   2100.0      1300.0
# mercedes_benz          2900.0   4000.0   7150.0  12200.0   6500.0      1550.0
# mini                   5500.0   4200.0   3000.0  12999.0   7600.0      7300.0
# mitsubishi              980.0    999.0   1390.0   4650.0   1800.0      1200.0
# nissan                 1275.0   3999.5   3300.0   4950.0   9500.0      1250.0
# opel                   1099.0   1600.0   3499.0   3650.0   2150.0      1200.0
# peugeot                1350.0   2725.0   3950.0   3799.0   4140.0      1499.0
# porsche               15695.0   8900.0      NaN  31500.0  39980.0         NaN
# renault                 999.0   2199.0   2150.0   3700.0   2000.0      1199.0
# rover                   799.0    899.0    450.0   2300.0    900.0       850.0
# saab                   1499.5    474.5      NaN   4500.0   1300.0         NaN
# seat                   1600.0    999.0   5000.0      NaN   3375.0      1950.0
# skoda                  2999.0   3999.0   5990.0   4745.0   2950.0      3800.0
# smart                  2000.0   3190.0      NaN   4200.0   3699.0      2700.0
# sonstige_autos          650.0   2900.0   3975.0  13900.0  19999.0      3400.0
# subaru                  900.0    999.0   2500.0   8900.0  15800.0       990.0
# suzuki                 1650.0   2550.0   1700.0   1800.0    450.0      3000.0
# toyota                 3400.0   4100.0   5300.0   5700.0   2674.5      3500.0
# trabant                 777.5   2199.0      NaN   5250.0   3600.0      1999.0
# volkswagen             1700.0   2650.0   6685.0   4200.0   9700.0      1599.0
# volvo                  1295.0  10650.0      NaN  10850.0   4900.0      2350.0
#
# vehicleType       kombi  limousine      suv
# brand
# alfa_romeo       2200.0     1998.5      NaN
# audi             7000.0     3990.0  23550.0
# bmw              5990.0     5990.0  12849.5
# chevrolet        3050.0     4275.0   9199.0
# chrysler         2750.0     1950.0   4050.0
# citroen          2300.0     2550.0  11690.0
# dacia            3555.0     2950.0   9500.0
# daewoo            875.0      849.0   1900.0
# daihatsu         3099.5     2800.0   1850.0
# fiat             1370.0     1600.0   5900.0
# ford             1750.0     1990.0  12000.0
# honda            3750.0     3000.0   6375.0
# hyundai          7999.5     4525.0   6750.0
# jaguar           5500.0     5500.0      NaN
# jeep                NaN        NaN   7900.0
# kia              1650.0     3100.0   7825.0
# lada              700.0     2210.5   3500.0
# lancia           1190.0     1799.0      NaN
# land_rover       2275.0      875.0  13325.0
# mazda            2750.0     1800.0  11992.5
# mercedes_benz    4499.0     4100.0  14300.0
# mini            10750.0     8800.0  17700.0
# mitsubishi       1200.0     1500.0   5200.0
# nissan           1500.0     2000.0   8900.0
# opel             1999.0     1650.0   4600.0
# peugeot          2500.0     2499.0  11300.0
# porsche             NaN    49900.0  18990.0
# renault          1900.0     1350.0   8900.0
# rover            2249.5      990.0   2800.0
# saab             2824.5     2224.5  10999.5
# seat             7250.0     4300.0   9799.0
# skoda            5800.0     4000.0  13350.0
# smart            2000.0     2650.0      NaN
# sonstige_autos   4583.5     6700.0  10350.0
# subaru           1900.0     5500.0   2290.0
# suzuki           1200.0     4190.0   4250.0
# toyota           4500.0     3800.0   7500.0
# trabant          1400.0     1250.0  14500.0
# volkswagen       3400.0     3300.0  14800.0
# volvo            1950.0     3450.0  13900.0
